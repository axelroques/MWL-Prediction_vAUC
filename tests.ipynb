# %%
# %load_ext autoreload

from mwl_vAUC import Predictor
from mwl_vAUC import Data

from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='talk', fscale=1.4, spines=False, gridlines='--')

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Compute Features

# %%
# %autoreload

data = Data(compute_features=True)

# %% [markdown]
# ## Load Features

# %%
# %autoreload

data = Data(compute_features=False)
# Out:
# Loading features... Done!

# %%
data.features_list
# Out:
# ['std_helico_altitude',
#  'mean_cross_helico_altitude',
#  'std_helico_yaw',
#  'mean_cross_helico_yaw',
#  'mean_helico_pitch',
#  'std_helico_pitch',
#  'mean_cross_helico_pitch',
#  'mean_helico_roll',
#  'std_helico_roll',
#  'mean_cross_helico_roll',
#  'gaze_ellipse_area',
#  'proportion_time_spent_Unknown',
#  'proportion_time_spent_Outside View',
#  'proportion_time_spent_Warning Panel',
#  'proportion_time_spent_Analog instruments',
#  'proportion_time_spent_PFDs & NDs',
#  'proportion_time_spent_CPDS',
#  'proportion_time_spent_GNS',
#  'proportion_time_spent_APMS',
#  'proportion_time_spent_ICPs',
#  'proportion_time_spent_ACUs',
#  'proportion_time_spent_Over Head Panel',
#  'proportion_time_spent_ADF, XPDR & RCU',
#  'proportion_time_spent_Front Panel',
#  'time_spent_ap_horz_mode_NONE',
#  'time_spent_ap_horz_mode_SAS',
#  'time_spent_ap_horz_mode_HDG',
#  'time_spent_ap_horz_mode_NAV_NMS',
#  'time_spent_ap_horz_mode_NAV_VOR',
#  'time_spent_ap_horz_mode_APP_LOC',
#  'time_spent_ap_horz_mode_APP_VORA',
#  'time_spent_ap_horz_mode_GO_AROUND',
#  'time_spent_ap_horz_mode_OTHER',
#  'time_spent_ap_vert_mode_NONE',
#  'time_spent_ap_vert_mode_SAS',
#  'time_spent_ap_vert_mode_IAS',
#  'time_spent_ap_vert_mode_ALT',
#  'time_spent_ap_vert_mode_ALTA',
#  'time_spent_ap_vert_mode_VS',
#  'time_spent_ap_vert_mode_GS',
#  'time_spent_ap_vert_mode_GO_AROUND',
#  'time_spent_ap_vert_mode_OTHER',
#  'mean_breathing_rate',
#  'std_breathing_rate',
#  'mean_heart_rate',
#  'std_heart_rate',
#  'mean_ibi',
#  'std_ibi',
#  'mean_cmd_coll',
#  'std_cmd_coll',
#  'mean_cross_cmd_coll',
#  'mean_cmd_yaw',
#  'std_cmd_yaw',
#  'mean_cross_cmd_yaw',
#  'mean_cmd_pitch',
#  'std_cmd_pitch',
#  'mean_cross_cmd_pitch',
#  'mean_cmd_roll',
#  'std_cmd_roll',
#  'mean_cross_cmd_roll',
#  'mean_force_coll',
#  'std_force_coll',
#  'mean_cross_force_coll',
#  'mean_force_yaw',
#  'std_force_yaw',
#  'mean_cross_force_yaw',
#  'mean_force_pitch',
#  'std_force_pitch',
#  'mean_cross_force_pitch',
#  'mean_force_roll',
#  'std_force_roll',
#  'mean_cross_force_roll',
#  'proportion_time_spent_coms',
#  'mean_fixation_duration',
#  'mean_saccade_duration',
#  'mean_saccade_amplitude']

# %% [markdown]
# ## Data Subselection

# %%
# %autoreload

data.selectFeatures(
    exclude_files=[],
    exclude_pilots=[2]
)
# Out:
# The following features were removed:

# %% [markdown]
# # Mental Load Prediction

# %% [markdown]
# ## Training

# %% [markdown]
# **Possible ground truths:**
# - Self-assessment:
#     - 'oral_declaration'
# - NASA-TLX related:
#     - 'mean_NASA_tlx'
#     - 'effort'
#     - 'performance'
#     - 'frustration'
#     - 'mental_demand'
#     - 'physical_demand'
#     - 'temporal_demand'
# - Theoretical NASA-TLX related:
#     - 'mean_theoretical_NASA_tlx'
#     - 'theoretical_effort'
#     - 'theoretical_mental_demand'
#     - 'theoretical_physical_demand'
#     - 'theoretical_temporal_demand'

# %%
# %autoreload

pred = Predictor(
    data,
    ground_truth='oral_declaration', 
    train_prop=0.8,
    n_iterations=10,
    auc_threshold=0.6,
    tolerance=0.1,
    heuristics=[
        'gaze_ellipse_area', 'mean_ibi', 
        'mean_saccade_duration', 'mean_saccade_amplitude'
    ],
    add_noise=False,
)

# %%
# %autoreload
AUCs, individual_AUCs_mean, \
    individual_AUCs_median, feature_contributions = pred.fit_predict()
# Out:
# Individual AUC via nan matrix for pilot 2:
# 	Mean=0.873± 0.115
# 	25%=0.829; Median=0.925; 75%=0.933
# Individual AUC via nan matrix for pilot 3:
# 	Mean=0.688± 0.121
# 	25%=0.625; Median=0.727; 75%=0.790
# Individual AUC via nan matrix for pilot 4:
# 	Mean=0.596± 0.336
# 	25%=0.475; Median=0.722; 75%=0.844
# Individual AUC via nan matrix for pilot 5:
# 	Mean=0.690± 0.271
# 	25%=0.542; Median=0.778; 75%=0.900
# Individual AUC via nan matrix for pilot 6:
# 	Mean=0.904± 0.082
# 	25%=0.856; Median=0.913; 75%=0.956
# Individual AUC via nan matrix for pilot 7:
# 	Mean=0.721± 0.038
# 	25%=0.706; Median=0.746; 75%=0.748
# Individual AUC via nan matrix for pilot 8:
# 	Mean=0.817± 0.168
# 	25%=0.738; Median=0.787; 75%=1.000
#
# AUC on test sets: Mean=0.773; std=0.108
# Features contribution to the model:
# 	feature_oral_declaration_std_helico_yaw: 10
# 	feature_oral_declaration_std_helico_pitch: 10
# 	feature_oral_declaration_std_helico_roll: 10
# 	feature_oral_declaration_std_helico_altitude: 9
# 	feature_oral_declaration_proportion_time_spent_CPDS: 7
# 	feature_oral_declaration_mean_cross_helico_yaw: 6
# 	feature_oral_declaration_proportion_time_spent_Warning Panel: 6
# 	feature_oral_declaration_proportion_time_spent_Analog instruments: 5
# 	feature_oral_declaration_std_heart_rate: 3
# 	feature_oral_declaration_mean_saccade_duration: 3
# 	feature_oral_declaration_mean_helico_pitch: 2
# 	feature_oral_declaration_mean_saccade_amplitude: 1
# 	feature_oral_declaration_mean_cross_helico_altitude: 0
# 	feature_oral_declaration_mean_cross_helico_pitch: 0
# 	feature_oral_declaration_mean_helico_roll: 0
# 	feature_oral_declaration_mean_cross_helico_roll: 0
# 	feature_oral_declaration_gaze_ellipse_area: 0
# 	feature_oral_declaration_proportion_time_spent_Unknown: 0
# 	feature_oral_declaration_proportion_time_spent_Outside View: 0
# 	feature_oral_declaration_proportion_time_spent_PFDs & NDs: 0
# 	feature_oral_declaration_proportion_time_spent_GNS: 0
# 	feature_oral_declaration_proportion_time_spent_APMS: 0
# 	feature_oral_declaration_proportion_time_spent_ICPs: 0
# 	feature_oral_declaration_proportion_time_spent_ACUs: 0
# 	feature_oral_declaration_proportion_time_spent_Over Head Panel: 0
# 	feature_oral_declaration_proportion_time_spent_ADF, XPDR & RCU: 0
# 	feature_oral_declaration_proportion_time_spent_Front Panel: 0
# 	feature_oral_declaration_time_spent_ap_horz_mode_NONE: 0
# 	feature_oral_declaration_time_spent_ap_horz_mode_SAS: 0
# 	feature_oral_declaration_time_spent_ap_horz_mode_HDG: 0
# 	feature_oral_declaration_time_spent_ap_horz_mode_NAV_NMS: 0
# 	feature_oral_declaration_time_spent_ap_horz_mode_NAV_VOR: 0
# 	feature_oral_declaration_time_spent_ap_horz_mode_APP_LOC: 0
# 	feature_oral_declaration_time_spent_ap_horz_mode_APP_VORA: 0
# 	feature_oral_declaration_time_spent_ap_horz_mode_GO_AROUND: 0
# 	feature_oral_declaration_time_spent_ap_horz_mode_OTHER: 0
# 	feature_oral_declaration_time_spent_ap_vert_mode_NONE: 0
# 	feature_oral_declaration_time_spent_ap_vert_mode_SAS: 0
# 	feature_oral_declaration_time_spent_ap_vert_mode_IAS: 0
# 	feature_oral_declaration_time_spent_ap_vert_mode_ALT: 0
# 	feature_oral_declaration_time_spent_ap_vert_mode_ALTA: 0
# 	feature_oral_declaration_time_spent_ap_vert_mode_VS: 0
# 	feature_oral_declaration_time_spent_ap_vert_mode_GS: 0
# 	feature_oral_declaration_time_spent_ap_vert_mode_GO_AROUND: 0
# 	feature_oral_declaration_time_spent_ap_vert_mode_OTHER: 0
# 	feature_oral_declaration_mean_breathing_rate: 0
# 	feature_oral_declaration_std_breathing_rate: 0
# 	feature_oral_declaration_mean_heart_rate: 0
# 	feature_oral_declaration_mean_ibi: 0
# 	feature_oral_declaration_std_ibi: 0
# 	feature_oral_declaration_mean_cmd_coll: 0
# 	feature_oral_declaration_std_cmd_coll: 0
# 	feature_oral_declaration_mean_cross_cmd_coll: 0
# 	feature_oral_declaration_mean_cmd_yaw: 0
# 	feature_oral_declaration_std_cmd_yaw: 0
# 	feature_oral_declaration_mean_cross_cmd_yaw: 0
# 	feature_oral_declaration_mean_cmd_pitch: 0
# 	feature_oral_declaration_std_cmd_pitch: 0
# 	feature_oral_declaration_mean_cross_cmd_pitch: 0
# 	feature_oral_declaration_mean_cmd_roll: 0
# 	feature_oral_declaration_std_cmd_roll: 0
# 	feature_oral_declaration_mean_cross_cmd_roll: 0
# 	feature_oral_declaration_mean_force_coll: 0
# 	feature_oral_declaration_std_force_coll: 0
# 	feature_oral_declaration_mean_cross_force_coll: 0
# 	feature_oral_declaration_mean_force_yaw: 0
# 	feature_oral_declaration_std_force_yaw: 0
# 	feature_oral_declaration_mean_cross_force_yaw: 0
# 	feature_oral_declaration_mean_force_pitch: 0
# 	feature_oral_declaration_std_force_pitch: 0
# 	feature_oral_declaration_mean_cross_force_pitch: 0
# 	feature_oral_declaration_mean_force_roll: 0
# 	feature_oral_declaration_std_force_roll: 0
# 	feature_oral_declaration_mean_cross_force_roll: 0
# 	feature_oral_declaration_proportion_time_spent_coms: 0
# 	feature_oral_declaration_mean_fixation_duration: 0

# %% [markdown]
# ## Compare features set

# %%
# %autoreload

comparison, feature_contribution = pred.compareFeaturesSet(
    remove_feature_groups=[
        ['am']
    ]
)
# Out:
# Removing features in ['am']...
# The following features were removed: feature_NASA-TLX_std_helico_altitude, feature_NASA-TLX_mean_cross_helico_altitude, feature_NASA-TLX_std_helico_yaw, feature_NASA-TLX_mean_cross_helico_yaw, feature_NASA-TLX_mean_helico_pitch, feature_NASA-TLX_std_helico_pitch, feature_NASA-TLX_mean_cross_helico_pitch, feature_NASA-TLX_mean_helico_roll, feature_NASA-TLX_std_helico_roll, feature_NASA-TLX_mean_cross_helico_roll, feature_theoretical_NASA-TLX_std_helico_altitude, feature_theoretical_NASA-TLX_mean_cross_helico_altitude, feature_theoretical_NASA-TLX_std_helico_yaw, feature_theoretical_NASA-TLX_mean_cross_helico_yaw, feature_theoretical_NASA-TLX_mean_helico_pitch, feature_theoretical_NASA-TLX_std_helico_pitch, feature_theoretical_NASA-TLX_mean_cross_helico_pitch, feature_theoretical_NASA-TLX_mean_helico_roll, feature_theoretical_NASA-TLX_std_helico_roll, feature_theoretical_NASA-TLX_mean_cross_helico_roll, feature_oral_declaration_std_helico_altitude, feature_oral_declaration_mean_cross_helico_altitude, feature_oral_declaration_std_helico_yaw, feature_oral_declaration_mean_cross_helico_yaw, feature_oral_declaration_mean_helico_pitch, feature_oral_declaration_std_helico_pitch, feature_oral_declaration_mean_cross_helico_pitch, feature_oral_declaration_mean_helico_roll, feature_oral_declaration_std_helico_roll, feature_oral_declaration_mean_cross_helico_roll
# The following features were removed: feature_NASA-TLX_gaze_ellipse_area, feature_NASA-TLX_proportion_time_spent_Unknown, feature_NASA-TLX_proportion_time_spent_Outside View, feature_NASA-TLX_proportion_time_spent_Warning Panel, feature_NASA-TLX_proportion_time_spent_Analog instruments, feature_NASA-TLX_proportion_time_spent_PFDs & NDs, feature_NASA-TLX_proportion_time_spent_CPDS, feature_NASA-TLX_proportion_time_spent_GNS, feature_NASA-TLX_proportion_time_spent_APMS, feature_NASA-TLX_proportion_time_spent_ICPs, feature_NASA-TLX_proportion_time_spent_ACUs, feature_NASA-TLX_proportion_time_spent_Over Head Panel, feature_NASA-TLX_proportion_time_spent_ADF, XPDR & RCU, feature_NASA-TLX_proportion_time_spent_Front Panel, feature_NASA-TLX_time_spent_ap_horz_mode_NONE, feature_NASA-TLX_time_spent_ap_horz_mode_SAS, feature_NASA-TLX_time_spent_ap_horz_mode_HDG, feature_NASA-TLX_time_spent_ap_horz_mode_NAV_NMS, feature_NASA-TLX_time_spent_ap_horz_mode_NAV_VOR, feature_NASA-TLX_time_spent_ap_horz_mode_APP_LOC, feature_NASA-TLX_time_spent_ap_horz_mode_APP_VORA, feature_NASA-TLX_time_spent_ap_horz_mode_GO_AROUND, feature_NASA-TLX_time_spent_ap_horz_mode_OTHER, feature_NASA-TLX_time_spent_ap_vert_mode_NONE, feature_NASA-TLX_time_spent_ap_vert_mode_SAS, feature_NASA-TLX_time_spent_ap_vert_mode_IAS, feature_NASA-TLX_time_spent_ap_vert_mode_ALT, feature_NASA-TLX_time_spent_ap_vert_mode_ALTA, feature_NASA-TLX_time_spent_ap_vert_mode_VS, feature_NASA-TLX_time_spent_ap_vert_mode_GS, feature_NASA-TLX_time_spent_ap_vert_mode_GO_AROUND, feature_NASA-TLX_time_spent_ap_vert_mode_OTHER, feature_NASA-TLX_mean_breathing_rate, feature_NASA-TLX_std_breathing_rate, feature_NASA-TLX_mean_heart_rate, feature_NASA-TLX_std_heart_rate, feature_NASA-TLX_mean_ibi, feature_NASA-TLX_std_ibi, feature_NASA-TLX_mean_cmd_coll, feature_NASA-TLX_std_cmd_coll, feature_NASA-TLX_mean_cross_cmd_coll, feature_NASA-TLX_mean_cmd_yaw, feature_NASA-TLX_std_cmd_yaw, feature_NASA-TLX_mean_cross_cmd_yaw, feature_NASA-TLX_mean_cmd_pitch, feature_NASA-TLX_std_cmd_pitch, feature_NASA-TLX_mean_cross_cmd_pitch, feature_NASA-TLX_mean_cmd_roll, feature_NASA-TLX_std_cmd_roll, feature_NASA-TLX_mean_cross_cmd_roll, feature_NASA-TLX_mean_force_coll, feature_NASA-TLX_std_force_coll, feature_NASA-TLX_mean_cross_force_coll, feature_NASA-TLX_mean_force_yaw, feature_NASA-TLX_std_force_yaw, feature_NASA-TLX_mean_cross_force_yaw, feature_NASA-TLX_mean_force_pitch, feature_NASA-TLX_std_force_pitch, feature_NASA-TLX_mean_cross_force_pitch, feature_NASA-TLX_mean_force_roll, feature_NASA-TLX_std_force_roll, feature_NASA-TLX_mean_cross_force_roll, feature_NASA-TLX_proportion_time_spent_coms, feature_NASA-TLX_mean_fixation_duration, feature_NASA-TLX_mean_saccade_duration, feature_NASA-TLX_mean_saccade_amplitude, feature_theoretical_NASA-TLX_gaze_ellipse_area, feature_theoretical_NASA-TLX_proportion_time_spent_Unknown, feature_theoretical_NASA-TLX_proportion_time_spent_Outside View, feature_theoretical_NASA-TLX_proportion_time_spent_Warning Panel, feature_theoretical_NASA-TLX_proportion_time_spent_Analog instruments, feature_theoretical_NASA-TLX_proportion_time_spent_PFDs & NDs, feature_theoretical_NASA-TLX_proportion_time_spent_CPDS, feature_theoretical_NASA-TLX_proportion_time_spent_GNS, feature_theoretical_NASA-TLX_proportion_time_spent_APMS, feature_theoretical_NASA-TLX_proportion_time_spent_ICPs, feature_theoretical_NASA-TLX_proportion_time_spent_ACUs, feature_theoretical_NASA-TLX_proportion_time_spent_Over Head Panel, feature_theoretical_NASA-TLX_proportion_time_spent_ADF, XPDR & RCU, feature_theoretical_NASA-TLX_proportion_time_spent_Front Panel, feature_theoretical_NASA-TLX_time_spent_ap_horz_mode_NONE, feature_theoretical_NASA-TLX_time_spent_ap_horz_mode_SAS, feature_theoretical_NASA-TLX_time_spent_ap_horz_mode_HDG, feature_theoretical_NASA-TLX_time_spent_ap_horz_mode_NAV_NMS, feature_theoretical_NASA-TLX_time_spent_ap_horz_mode_NAV_VOR, feature_theoretical_NASA-TLX_time_spent_ap_horz_mode_APP_LOC,  ...

# %%
comparison
# Out:
#                  Features removed  Mean AUC   Std AUC  Median AUC pilot 3  \
# 0                              am  0.790336  0.111841            0.552083
# 1  aoi, asl, br, ecg, fc, rc, sed  0.758820  0.068189            0.663194
#
#    Median AUC pilot 4  Median AUC pilot 5  Median AUC pilot 6  \
# 0            0.837963            0.952381            0.944444
# 1            0.864583            0.812500            1.000000
#
#    Median AUC pilot 7  Median AUC pilot 8  Median AUC pilot 9  ...  \
# 0            0.972222            0.808594            0.833333  ...
# 1            0.880952            0.703704            0.870899  ...
#
#    First quartile AUC pilot 7  First quartile AUC pilot 8  \
# 0                    0.826111                    0.567057
# 1                    0.600000                    0.697090
#
#    First quartile AUC pilot 9  Third quartile AUC pilot 3  \
# 0                    0.635417                    0.645139
# 1                    0.832176                    0.719792
#
#    Third quartile AUC pilot 4  Third quartile AUC pilot 5  \
# 0                    1.000000                    1.000000
# 1                    0.890625                    0.885417
#
#    Third quartile AUC pilot 6  Third quartile AUC pilot 7  \
# 0                     0.97619                    0.986111
# 1                     1.00000                    0.916667
#
#    Third quartile AUC pilot 8  Third quartile AUC pilot 9
# 0                    1.000000                    0.937500
# 1                    0.804977                    0.917857
#
# [2 rows x 24 columns]

# %%
feature_contribution
# Out:
#                  Features removed  Mean AUC   Std AUC  \
# 0                              am  0.790336  0.111841
# 1  aoi, asl, br, ecg, fc, rc, sed  0.758820  0.068189
#
#    feature_oral_declaration_std_helico_altitude  \
# 0                                             0
# 1                                            10
#
#    feature_oral_declaration_mean_cross_helico_altitude  \
# 0                                                  2
# 1                                                  0
#
#    feature_oral_declaration_std_helico_yaw  \
# 0                                        0
# 1                                       10
#
#    feature_oral_declaration_mean_cross_helico_yaw  \
# 0                                               0
# 1                                               6
#
#    feature_oral_declaration_mean_helico_pitch  \
# 0                                           3
# 1                                           2
#
#    feature_oral_declaration_std_helico_pitch  \
# 0                                          0
# 1                                         10
#
#    feature_oral_declaration_mean_cross_helico_pitch  ...  \
# 0                                                 0  ...
# 1                                                 0  ...
#
#    feature_oral_declaration_mean_force_pitch  \
# 0                                          0
# 1                                          0
#
#    feature_oral_declaration_std_force_pitch  \
# 0                                        10
# 1                                         0
#
#    feature_oral_declaration_mean_cross_force_pitch  \
# 0                                                0
# 1                                                0
#
#    feature_oral_declaration_mean_force_roll  \
# 0                                         5
# 1                                         0
#
#    feature_oral_declaration_std_force_roll  \
# 0                                        8
# 1                                        0
#
#    feature_oral_declaration_mean_cross_force_roll  \
# 0                                               0
# 1                                               0
#
#    feature_oral_declaration_proportion_time_spent_coms  \
# 0                                                  3
# 1                                                  0
#
#    feature_oral_declaration_mean_fixation_duration  \
# 0                                                0
# 1                                                0
#
#    feature_oral_declaration_mean_saccade_duration  \
# 0                                               1
# 1                                               0
#
#    feature_oral_declaration_mean_saccade_amplitude
# 0                                                0
# 1                                                2
#
# [2 rows x 79 columns]
